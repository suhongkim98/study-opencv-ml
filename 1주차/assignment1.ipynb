# %%
import numpy as np
import cv2
import matplotlib.pylab as plt

# %% [markdown]
# # 이미지 불러오기

# %%
img = cv2.imread('image.jpg')
plt.imshow(img)

# %% [markdown]
# # BGR2RGB

# %%
img2 = img.copy()
img2[:,:,0] = img[:,:,2]
img2[:,:,2] = img[:,:,0]
plt.imshow(img2) #201704017김수홍
